# %% [markdown]
# # 3.1_T-SQL'de Fonksiyonlar Giriş
#
# T-SQL, içerisinde kullanabileceğin bir çok fonksiyon barındırır.
#
# Fonksiyonlar, içerisine hiç parametre almayan veya bir ya da birden fazla parametre alabilen içerisinde hedefe yönelik belirli işlemler gerçekleştirip bize sonuç dönen bir yapıdır.
#
# T-SQL'de kullanıma hazır fonksiyonlar da bulunur. Biz de fonksiyon yazabiliriz.
#
# ## T-SQL'deki fonksiyon türleri
#
# * **String Fonksiyonları**
#     * String ifadeler üzerinde yaptığımız işlemler için kullandığımız fonksiyonlar
# * **Datetime Fonksiyonları**
#     * Tarih ve saat işlemleri için kullandığımız fonksiyonlar
# * **Matematik Fonksiyonları**
#     * Matematiksel işlemleri gerçekleştirmek için kullandığımız fonksiyonlar
# * **Tip Dönüşüm Fonksiyonları**
#     * Veri tipleri arasında dönüşüm sağlamak için kullandığımız fonksiyonlar
# * **Sistem Fonksiyonları**
#     * Sistemle ilgili bilgiler getiren fonksiyonlar
#
# ---

# %% [markdown]
# # 3.2_String Fonksiyonları Giriş
#
# Veritabanlarında çalışırken en çok karşılaştığımız veri tiplerinden birisi *string* veri tipleridir.  **Char**, **varchar**, **nchar**, **nvarchar** veri tipleri string veri tipleridir.
#
# Stringler üzerinde rahat çalışabilmemizi sağlayan T-SQLdeki bu fonksiyonlara string fonksiyonları denir.
#
# T-SQL'deki bu string fonksiyonları kütüphanesi oldukça zengindir;
# <img src = "https://i.hizliresim.com/9g31q7t.png">
#
# String fonksiyonları hakkında ayrıntılı bilgi için google'a *[t sql string functions](https://learn.microsoft.com/en-us/sql/t-sql/functions/string-functions-transact-sql?view=sql-server-ver16)* yazabilirsin.
#
# ---

# %% [markdown]
# # 3.3_<code>ASCII</code> Fonksiyonu
#
# ### Tanım
# Bir karakterin ASCII değerini (0-255 arasındaki rakamsal değerini) döndürür.
#
# ### Kullanım
# <img src = "https://i.hizliresim.com/el2n297.png">
# <img src = "https://i.hizliresim.com/f2zj4na.png">
#
# ### Not
# Verinin içerisinde kirli veri varsa, istenmeyen değerler varsa, gözle görünmeyen karakterler varsa ve bu karakterlerin temizlenmesi gerekiyorsa bu karaktere karşılık gelen ASCII değerini bulup temizleyebiliriz.
#
# ----

# %% [markdown]
# # 3.4_<code>CHAR</code> Fonksiyonu
#
# ### Tanım
# ASCII fonksiyonunun tam tersidir. İçine ASCII değeri girilen karakteri döndürür.
#
# ### Kullanım
# <img src = "https://i.hizliresim.com/js4kd86.png">
#
# ### Not
# CHAR fonksiyonuna 13 değerini girdiğimizde bize enter karakterini vermez. Bu yüzden farklı bir yerden veri çekerken kirli verilerin yakalanmasında ASCII ile birlikte kullanılır.
#
# ---

# %% [markdown]
# # 3.5_<code>CONCAT</code> Fonksiyonu
#
# ### Tanım
#
# Birden fazla string ifadeyi birleştirmek için kullandığımız fonksiyondur.
#
# ### Kullanım
#
# <img src = "https://i.hizliresim.com/f6uiogk.png">
#
# ### Not
#
# SQL Server'da string birleştirme şu şekilde de yapılabilir;
#
# <img src = "https://i.hizliresim.com/jh1cz2p.png">
#
# **'+' operatörünü her zaman düzgün kullanamayabilirsin. O yüzden sen string birleştirmelerde daima CONCAT kullan.**
#
# ----

# %% [markdown]
# # 3.6_<code>LEFT</code>/<code>RIGHT</code> Fonksiyonları
#
# ### Tanım
#
# Bir stringin sağından ve solundan belirli karakterleri alabildiğimiz string fonksiyonlarıdır.
#
# ### Kullanım
#
# <img src = "https://i.hizliresim.com/dkozjrt.png">
#
# ### Not
#
# Belirli bir karakteri buldurup o karaktere gidip, karakterin sağından veya solundan o karakter kadar bölümü aldırmak için kullanılır.
#
# ----

# %% [markdown]
# # 3.7_<code>TRIM</code>/<code>LTRIM</code>/<code>RTRIM</code> Fonksiyonları
#
# ### Tanım
#
# Trim kelimesi İngilizce'de kırpmak, temizlemek anlamındadır. String fonksiyonlarında TRIM, ifadenin başındaki ve sonundaki boşluk karakterlerinden kurtulmaya yarayan fonksiyondur.
#
# * LTRIM fonksiyonu stringin başındaki boşlukları temizler. (Left TRIM)
# * RTRIM fonksiyonu stringin sonundaki boşlukları temizler. (Right TRIM)
# * TRIM fonksiyonu stringin başında ve sonundaki boşlukları temizler.
#
# ### Kullanım
#
# <img src = "https://i.hizliresim.com/suc7qn7.png">
#
# ### Not
#
# TRIM fonksiyon SQL Server 2012 öncesinde yoktu. TRIM fonksiyonu yerine aşağıdaki şekilde bir kullanım tercih ediliyordu;
#
# <img src = "https://i.hizliresim.com/cfh4v4v.png">
#
# ----

# %% [markdown]
# # 3.8_<code>LOWER</code>/<code>UPPER</code>/<code>REVERSE</code>/<code>REPLICATE</code> Fonksiyonları
#
# ### Tanım
#
# LOWER, string ifadeyi küçük harfli haline çevirir.
# UPPER, string ifadeyi büyük harfli haline çevirir.
# REVERSE, stringi tersten yazdırır.
# REPLICATE, string ifadeyi belirlediğimiz sayıda tekrar ettirir.
#
# ### Kullanım
#
# <img src = "https://i.hizliresim.com/ew2g7gu.png">
#
# ### Not
#
# Fonksiyonlar, SQL Server hangi dildeyse (**collation**: Turkish_CI_AS) o dile göre büyültme veya küçültme yapar.
#
# <img src = "https://i.hizliresim.com/onwqj3g.png">
#
# * 'DATA SCIENCE', LOWER ile 'data scıence' olurken,
# * 'data science', UPPER ile 'DATA SCİENCE' olur.
#
# REVERSE fonksiyonu büyük verilerde performans kazancı oluşturmak için kullanılır. Diyelim bir string ifadenin bir değerden sonraki kısmını aratmak istiyorsun bu noktada index kullanamayacağın için performanslı bir arama yapamazsın. Bunun yerine ifadeyi farklı bir kolonda tersine çevirip tersinden arama yaparak hızlı sonuç elde edebilirsin.
#
# REPLICATE fonksiyonunu belirli bir digiti geçmeyecek şekilde akıllı kod oluştururken kullanabiliriz. Yani diyelim URUNLER tablosu için URUNKODU kolonunu oluşturacağız ve bu kod URUN00001'den başlayıp URUN99999'lara kadar devam edebilecek. Bu noktada bu atamaları yaparken 0 değerini gelen değere göre çoğaltarak ekleme yapabiliriz.
#
# <img src = "https://i.hizliresim.com/cgzelzv.png">
#
# **<code>LEN</code>** fonksiyonu bir string dizisinin karakter uzunluğunu verir.
#
# ----

# %% [markdown]
# # 3.9_<code>REPLACE</code> Fonksiyonu
#
# ### Tanım
#
# Bir string içerisinde aradığımız ifadeyi farklı bir string ifade ile değiştirmek için kullanılır.
#
# ### Kullanım
#
# Üç tane parametresi var.
# 1. Mevcut string ifadesi
# 2. Aradığımız ifade
# 3. Yeni ifade
#
# <img src = "https://i.hizliresim.com/oz54mv1.png">
#
# ### Not
#
# Özellikle kirli veriyi temizlemek için kullanılır. Klasik olarak doldurulan bir anket formu düşünürsek, kullanıcılardan 'İstanbul' yazması beklenirken 'Istanbul', 'İst.', 'İst' yazabilir. Bu değerler REPLACE ile 'İstanbul' olacak şekilde değiştirilebilir.
#
# ----

# %% [markdown]
# # 3.10_<code>SUBSTRING</code> Fonksiyonu
#
# ### Tanım
#
# Belirli bir başlangıç noktasından belirli bir uzunluktaki bilgiyi almak için kullandığımız fonksiyondur.
#
# ### Kullanım
#
# <img src = "https://i.hizliresim.com/hlc16cs.png">
#
# ### Not
#
# Daha çok string parse işlemleri için kullanılır. Örneğin bir HTML ifadeden belirli karakterlere göre aradığımız kısmı almak için kullanabiliriz.
#
# ---

# %% [markdown]
# # 3.11_<code>CHARINDEX</code> Fonksiyonu
#
# ### Tanım
#
# String ifade içerisinde aradığımız bir ifadenin nerede olduğunun index bilgisini veren fonksiyondur.
#
# ### Kullanım
#
# İki parametre alır. Önce aradığın ifadeyi daha sonra içinde aradığın ifadeyi alır.
#
# <img src = "https://i.hizliresim.com/7c5ioqt.png">
#
# ### Not
#
# CHARINDEX daha çok yerini bildiğin string ifadelere göre parçalama işlemleri yapmak için kullanılır. Örneğin HTML bir ifadedeki taglerin yerini öğrenip o tagler arasında yazan ifadeleri elde edebiliriz. (HTML parsing işlemleri için yoğunlukla kullanılır)
#
# LEFT, RIGHT, SUBSTRING fonksiyonları ile ortaklaşa güzel çalışır.
#
# Eğer aradığı ifadeyi string içerisinde bulamazsa 0 döndürür.
#
# ---

# %% [markdown]
# # 3.12_<code>STRING_SPLIT</code> Fonksiyonu
#
# ### Tanım
#
# String bir ifadeyi belirli bir ayraca göre parçalayıp, parçaları tablo olarak dönmesini sağlayan fonksiyondur. Table-valued bir fonksiyondur. Yani sonuç olarak skalar bir değer değil, bir tablo döndürür.
#
# ### Kullanım
#
# Tablo döndüreceği için doğrudan SELECT ile kullanılmaz. SELECT * FROM ile kullanılır.
#
# İki adet parametre alır. İlki parçalamak istediğimiz string ifade, ikincisi parçalamak için kullanacağımız ayraç karakteridir.
#
# <img src = "https://i.hizliresim.com/bmxwaf1.png">
#
# ### Not
#
# Ayraç olarak tek bir karakter alır.
#
# ----

# %% [markdown]
# # 3.13_String Fonksiyonları Alıştırma 1
#
# ### Soru
#
# <img src = "https://i.hizliresim.com/otypqms.png">
#
# ****Eklediğin bir kolonun veya farklı bir nesnenin anında tanınır olmasını istiyorsan Ctrl + Shift + R yap.**
#
# ### Cevap
#
# <img src = "https://i.hizliresim.com/1hkowd1.png">
#
# ---

# %% [markdown]
# # 3.14_String Fonksiyonları Alıştırma 2
#
# ### Soru
#
# <img src = "https://i.hizliresim.com/qnpwxm6.png">
#
# ### Cevap
#
# <img src = "https://i.hizliresim.com/jih21n3.png">
#
# SQL Server'da default sonuç grid türünde olduğu ve enter karakter gridde anlaşılamadığı için üstteki sekmelerden sonucu text olarak görmeyi seçerek enter karakterinin etkisini görebilirsin.
#
# <img src = "https://i.hizliresim.com/2c0gnrg.png">
#
# ---

# %% [markdown]
# # 3.15_String Fonksiyonları Alıştırma 3
#
# ### Soru
#
# <img src = "https://i.hizliresim.com/jdzwqi3.png">
#
# ### Cevap
#
# <img src = "https://i.hizliresim.com/p5xdyel.png">
#
# ****Eğer elindeki veri İngilizce kelimeler içeriyorsa ve senin collation'ın Turkish ise bu tür kelimeleri UPPER veya LOWER içerisine koyarken collate bilgisini ver.**
#
# <img src = "https://i.hizliresim.com/41f9rkw.png">
#
# ----

# %% [markdown]
# # 3.16_String Fonksiyonları Alıştırma 4
#
# ### Soru
#
# <img src = "https://i.hizliresim.com/7sz4e37.png">
#
# ### Cevap
#
# <img src = "https://i.hizliresim.com/rpntqxc.png">
#
# Farklı yollardan da bu sonucu elde edebilirsin.
#
# <img src = "https://i.hizliresim.com/sijeq0l.png">
#
# ----

# %% [markdown]
# # 3.17_String Fonksiyonları Alıştırma 5
#
# ### Soru
#
# <img src = "https://i.hizliresim.com/9nukwi8.png">
#
# ### Cevap
#
# <img src = "https://i.hizliresim.com/oe5lmt4.png">
#
# #### Benim cevabım
#
# <img src = "https://i.hizliresim.com/bmci2re.png">
#
# ---

# %% [markdown]
# # 3.18_String Fonksiyonları Alıştırma 6
#
# ### Soru
#
# <img src = "https://i.hizliresim.com/azw2iwo.png">
#
# ### Cevap
#
# <img src = "https://i.hizliresim.com/l02l8x4.png">
#
# ----

# %% [markdown]
# # 3.19_String Fonksiyonları Alıştırma 7
#
# ### Soru
#
# <img src = "https://i.hizliresim.com/4b7dv2n.png">
#
# ### Cevap
#
# <img src = "https://i.hizliresim.com/rqdq85z.png">
#
# ---

# %% [markdown]
# # 3.20_String Fonksiyonları Alıştırma 8
#
# ### Soru
#
# <img src = "https://i.hizliresim.com/bixkpw5.png">
#
# ### Cevap
#
# <img src = "https://i.hizliresim.com/5tghqhd.png">
#
# ---

# %% [markdown]
# # 3.21_String Fonksiyonları Alıştırma 9
#
# ### Soru
#
# <img src = "https://i.hizliresim.com/8e9687a.png">
#
# Exif bilgisi, bir fotoğraf makinesi ile çekilmiş fotoğrafın ekstra bilgilerini tutar.
#
# ### Cevap
#
# <img src = "https://i.hizliresim.com/q4l9svt.png">
#
# Text sonuçları için her bir kolondan gelen maksimum bilgi default olarak 256 karakter olarak ayarlanmıştır. Daha fazla veri gelsin istiyorsan **Query Options**'dan maksimumu yükseltmen gerekir.
