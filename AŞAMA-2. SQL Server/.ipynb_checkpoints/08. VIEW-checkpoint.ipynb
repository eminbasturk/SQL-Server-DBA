# %% [markdown]
# # 1. VIEW Giriş
#
# * Karmaşık bir sorgu düşünelim.
#
# <img src = "https://i.hizliresim.com/tfaa58b.png">
#
# * Bu şekilde ihtiyacın olan ve sıkça kullanabileceğin karmaşık sorguları her seferinde yazmak istemeyebilir ve verdiğin aliaslar ile çağırmak isteyebilirsin. Bu durumlarda VIEWlar işini görür.
#
# * **VIEWlar her SQL Server objesi gibi CREATE ile oluşturulur, DROP ile silinir ve ALTER ile değiştirilir.**
# * VIEWları SSMS'de wizard ile de oluşturabilirsin ancak **SQL ile uğraşan birisi bu işlemleri komutlarla yapmalıdır, sürükle bıraklarla değil.**
#
# * VIEW komutlar ile aşağıdaki şekilde oluşturulur.
#
# <img src = "https://i.hizliresim.com/bcbeajy.png">
#
# * SELECT ile başlayan alan sorguyu temsil eder.
#
# * Oluşturulan VIEWları bir tablo gibi kullanabilirsin.
#
# <img src = "https://i.hizliresim.com/dlx8u4c.png">
#
# * **Kısaca, bir SQL sorgusunu tablo gibi kullanabildiğin yapılara VIEW denir.**

# %% [markdown]
# # 2. VIEW Uygulama 1 - Merkezi Değişim Güncellenmesi
#
# * Diyelim bir şirketin bilgi işlem departmanında çalışıyorsun ve senden aylara göre satışların görülebileceği bir rapor istendi.
# -----
# * Kodu böyle;
# <img src = "https://i.hizliresim.com/73z2s5x.png" width = 600>
#
# * Çıktısı da böyle olan;
# <img src = "https://i.hizliresim.com/6xyzamu.png">
#
# * Raporu Excelde görüntülemek için yazdığın sorguyu kopyala. Excel üzerinde;
# * **Veri** -> **Diğer Kaynaklardan** -> **SQL Server'dan** -> **Veri Bağlantı Sihirbazı**'na;
#     * *1. Sunucu adı:*
#     * *2. Oturum açma kimlik bilgileri:* ni girdikten sonra (normalde yetkili (SA) olarak girilmez, rapor görüntülemek için girilir)
# * ilgili databasei seçip son dedikten sonra **Veri Al**'dan *Özellikler*e tıklayıp **Bağlantı Özellikleri**nde *Tanım*ın altında *Komut türü* olarak SQL'i seçip, *Komut metni*ne sorgunu yapıştırırsan sorgunun sonucunu Excelde bu şekilde görüntüleyebilirsin;
#
# <img src = "https://i.hizliresim.com/pag1ocw.png">
#
# * Sayfa her yenilendiğinde veriler otomatik olarak çekilip excele getirilir.
# ----
# * Raporu alan kişiler ayları sayı olarak görmek yerine ay isimleriyle görmek isteyebilir.
# * Bu durumda **CASE-WHEN** ile ayları isimlerine eşleyebilirsin. (****Eğer bir değer üzerinden eşleme varsa direkt CASE'den sonra belirt.**)
#
# <img src = "https://i.hizliresim.com/namowc5.png" width = 300>
#
# * Değişen kodu tekrar kopyalayıp excel raporları üzerinden değiştirebilirsin. Bunun için **Veri**'den *Özellikler* deyip *Bağlantı Özellikleri*ne tıklayarak *Tanım*'dan *Komut metni*ni değiştirebilirsin.
#
# <img src = "https://i.hizliresim.com/bgw8wc0.png">
#
# * Raporu alan kişiler ay isimlerini uzun halleriyle değil de kısaltılmış halde görmek isteyebilirler.
# * Aynı şekilde CASE-WHENler içerisinde düzenlemeleri yapıp kopyalayıp Excele yapıştırabilirsin.
#
# ### Yukarıdaki işlerin hepsi zahmetli işlerdir.
#
# * Yazdığın sorguyu ilk halindeki gibi düşünerek VIEW olarak tanımla.
#
# <img src = "https://i.hizliresim.com/95eut9l.png" width = 600>
#
# * ****VIEWlarda tablolar için ORDER BY kullanılmaz. Ancak VIEWlar için kullanılabilir.**
#
# * **VIEWlar son kullanıcının görebileceği şekilde hazırlandığından kolon isimleri alias ile Türkçe olarak verilmesi normaldir. VIEWların güzel taraflarından biri budur.**
#
# * Yukarıdaki şekilde bir VIEW tanımladıktan sonra Excel içerisinde bu VIEWu şu şekilde çağırabilirsin.
#
# <img src = "https://i.hizliresim.com/yszvmvy.png">
#
# #### Eğer yine aylar sayı yerine isimle gözüksün istiyorsan;
# * Bu sefer Excelleri toplamana ve değiştirmene gerek yok. Direkt VIEW içerisinden **ALTER** ile değişiklik yaparak aynı sorgu üzerinden çekim yapabilirsin.
#
# <img src = "https://i.hizliresim.com/n0oh69f.png" width = 450>
#
# * **Bu durumda Excel üzerinde *Yenile* dediğin anda tablo yenilenir!!**
#
# <img src = "https://i.hizliresim.com/1vu81zb.png">
#
# * Ancak bu durumda da tablo aylara göre sıralandığı için alfabetik olarak önce Ağustos vs gelir. Bunun önüne geçmek için de tekrar VIEW içerisinde aylar numaralandırılır. Sonuç aşağıdaki gibidir:
#
# <img src = "https://i.hizliresim.com/jex800p.png">
#
# * ****Sadece merkezdeki raporu hazırlayan kişi değişiklik yapar. Kullanıcılardan dosya talebi ve yeniden dağıtma işlemleri istenmez!!!**
# * **Kodu sadeleştirir.**
# * **Türkçe alanlar barındırabilir.**
# * **VIEW'a Türkçe isim verilebilir.**
# * **Merkezden yönetip dağıtımı kolaylaştırır.**

# %% [markdown]
# # 3. VIEW Uygulama 2 - VIEW İçerisinden Başka Bir VIEW Sorgulama
#
# * Daha karmaşık bir sorgu düşünelim.
#
# <img src = "https://i.hizliresim.com/cepoldx.png">
#
# * <code>CONVERT()</code> bir verinin türünü başka bir veri türüne dönüştüren fonksiyon.
# * <code>DATEPART()</code> tarihten bir bölümü verir. Eğer **DW** girersen haftanın hangi gününde olduğunu verir. Ancak ingilizcede haftanın ilk günü Pazar olduğu için 1, Pazar gününe eşittir. Buna dikkat et.
#
# <img src = "https://i.hizliresim.com/rkmab7w.png">
#
# * Bu detayları aldıktan sonra bu sorguyu VIEW olarak kaydediyorum.
#
# <img src = "https://i.hizliresim.com/rnt6in4.png" width = 300>
#
# * Bu VIEW üzerinden farklı VIEWlar oluşturabilirsin.
#
# #### En çok satan 10 ürün kategorisini çeken bir VIEW
#
# <img src = "https://i.hizliresim.com/92lgmc2.png" width = 400>
#
# * Artık bu VIEW da her yerde kullanılabilir.
# * Örneğin Excelde;
#
# <img src = "https://i.hizliresim.com/gjjps1f.png">
#
# * **Excelde birden fazla rapor oluşturabilirsin. Aynı veritabanından oluşturmak için var olan sheeti kopyalarsın.**
#
# #### Mağaza analizi için bir VIEW
#
# * **VIEW oluştururken isimsiz kolon bulunamaz. Mesela aggregate function sonuçlarına isim vermen gerekir.**
#
# <img src = "https://i.hizliresim.com/fj32yjf.png" width = 500>
#
# * Excelde iki kolonun yerini değiştirmek istiyorsan. Kolonu kes ve yerine koyacağın kolona kesilen kolonu ekle.
#
# #### Müşteri analizi için bir VIEW
#
# <img src = "https://i.hizliresim.com/7u13eel.png">
#
# <img src = "https://i.hizliresim.com/5e1tyc8.png">
#
# * Eğer VIEW'da bir değişiklik yaparsan. Yani diyelim *TOP 1000* yerine *TOP 100* yazdın. Excelde yenilediğinde 1000 satır yerine 100 satır gelir.
#
# ### NOT
#
# * Normalde tablolarda eğer aggregate functions üzerinden bir koşul vermek istiyorsan GROUP BY'dan sonra **HAVING** kullanırsın. Ancak VIEWlaşmış bir nesne artık tablo gibi işlem görebildiğinden aynı işlemi **WHERE** ile yaparsın.
#
# * Toplam tutarı 10000'den fazla olan kullanıcıların Joinli tablo ve Viewlu sorguları;
#
# <img src = "https://i.hizliresim.com/fi7prsb.png">

# %% [markdown]
# # 4. VIEW Uygulama 4 - Performans Analizi ve Özet Tablolar
#
# * **VIEWlar genellikle raporlama için kullanılır.**
# * Raporlamalar için sıklıkla kullanılan araç Exceldir.
# * Diyelim satırlarda şehirler, sütunlarda da günler olacak şekilde günlere göre şehirlerdeki toplam sipariş tutarları istendi.
# * Bunun için elimizde bulunan **VW_SIPARIS_DETAYLI** VIEW'unu olduğu gibi Excele attığımız takdirde bunun Excele yansıması yaklaşık 4 dakika sürerdi. Daha sonradan Excelde özet tablo oluştursan bile çok fazlaca bir vakit kaybı yaşanmış olurdu.
# * Bunun yerine ihtiyacın olan verileri aşağıdaki gibi alırsan, Excelde de işin kolaylaşır.
#
# <img src = "https://i.hizliresim.com/n5kgc9v.png" width = 400>
#
# * Bu şekilde sorguyu excele atıp Pivot Tablo ekleyip, satırlara şehir, sütunlara haftanın günü, değerlere de toplam tutar eklenip kolonlar biçimlendirildiğinde çok kısa sürede aşağıdaki sonuç elde edilir.
#
# <img src = "https://i.hizliresim.com/qpyfn50.png">
#
# ### GIGACHAD
#
# <img src = "https://i.hizliresim.com/627dk4o.png">
