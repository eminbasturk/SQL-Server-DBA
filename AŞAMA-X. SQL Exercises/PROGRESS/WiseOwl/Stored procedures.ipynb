# %% [markdown]
# # 1. Nispeten kolay
#
# **Asia'daki ülkeleri göstermek için temel stored procedure**
#
# **ContinentId** değeri 1'e eşit olan tüm ülkeleri alfabetik sırayla listelemek için **uspCountriesAsia** adında bir stored procedure oluştur:
#
# <img src = "https://i.hizliresim.com/owvjmfr.png">
#
# * Procedureünü çalıştırdığında göstermesi gereken ilk birkaç ülke.
#
# Bir hatırlatma olarak, basic bir stored procedureün syntaxı şöyledir:
#
# <img src = "https://i.hizliresim.com/2kcw0ca.png">
#
# Bu işe yaradıysa, sorgunun metnini değiştirerek **uspCountriesEurope** adında kıta idsi 3 olan tüm ülkeleri listeleyen farklı bir procedure oluştur ve bunun işe yarayıp yaramadığını kontrol et.
#
# Tüm SQL Server Management Studio pencerelerini kapat. **Object Explorer**de **uspCountriesAsia** procedureünü bul ve modify et. Procedureü **CountryId**'yi de listeleyecek şekilde değiştir:
#
# <img src = "https://i.hizliresim.com/3mpv9rz.png">
#
# * Procedureünün çıktısı artık country idyi de içerir.
#
# İsteğe bağlı olarak, sorgunu **Basic procedures.sql** olarak kaydet ve ardından kapat.
#
# ### Basic procedures.sql
#
# <img src = "https://i.hizliresim.com/k65trc8.png">
#
# <img src = "https://i.hizliresim.com/guhxrgw.png">
#
# <img src = "https://i.hizliresim.com/gz68dek.png">
#
# <img src = "https://i.hizliresim.com/s9h99oi.png">

# %% [markdown]
# # 2. Nispeten kolay
#
# **Matt Smith'in Dr. Who bölümlerini listelemek için bir stored procedure oluştur**
#
# **Matt Smith**'in Doctor olarak yer aldığı tüm bölümleri listelemek için SQL'de bir **SELECT** ifadesi yaz:
#
# <img src = "https://i.hizliresim.com/3m79o8a.png">
#
# * **Matt Smith**in yer aldığı 44 bölümden ilk birkaçı.
#
# Bunun nasıl yapılacağına ilişkin iki ayrı talimat seti, kolay yolu ve "zor" yolu gösterek aşağıda gösterilmiştir. Kendine rahat hissettiğin yaklaşımı kullan!
#
# ## Kolay Yol
#
# Bir sorgu oluşturmanın kabul edilebilir Mickey Mouse yolu, Query Designer kullanmaktır. Önce New Query'de sağ tıkla ve şu seçeneği belirle:
#
# <img src = "https://i.hizliresim.com/ig5irks.png">
#
# * Management Studio düzenleyicisini kullanarak bir sorgu tasarlamayı seç.
#
# Şimdi bu sorguyu oluşturmak için tablolar, aliaslar, sıralama, filtreleme ve joinler ekle:
#
# <img src = "https://i.hizliresim.com/1qtrqh4.png">
#
# * Sorgunun son hali
#
# <code>OK</code> seçtiğinde, şimdi düzenleyebileceğin bir **SELECT** ifadesi göreceksin!
#
# ## Zor Yol
#
# Bir SQL ifadesi oluşturmanın diğer yolu, onu yazmaktır. SQL'de bir **SELECT** ifadesinin temel syntaxı şöyledir:
#
# <img src = "https://i.hizliresim.com/nehbu1g.png">
#
# İster zor ister kolay yolu seç, 44 Matt Smith bölümünü listeleyen bir SQL ifadesi kalmalıdır.
#
# ## Stored Procedure Oluşturma
#
# Stored procedure olarak depolamak için SQL'inin başına aşağıdakini ekle:
#
# <img src = "https://i.hizliresim.com/4c3048v.png">
#
# 44 filmi listelediğini görmek için stored procedureünü çalıştır. Şimdi scriptini, stored procedureünü yalnızca 2012'de yapılmış **Matt Smith**'in yer aldığı bölümleri listeleyecek şekilde değiştir, **WHERE** clause'undaki bu syntaxı kullan:
#
# <img src = "https://i.hizliresim.com/oply0gy.png">
#
# 6 bölüm listelediğini kanıtlamak için revize edilmiş stored procedureü çalıştır:
#
# <img src = "https://i.hizliresim.com/eu6pzn7.png">
#
# * 2012'de yapılan 6 Matt Smith bölümü.
#
# İsteğe bağlı olarak, bu SQL'i **Matt Smith Episodes.sql** olarak kaydet ve ardından kapat.
#
# ### Matt Smith Episodes.sql
#
# <img src = "https://i.hizliresim.com/dmg41o6.png">
#
# <img src = "https://i.hizliresim.com/ae9132j.png">

# %% [markdown]
# # 3. Nispeten kolay
#
# **Ağustos olaylarını göstermek için bir procedure oluştur**
#
# Bu alıştırmanın amacı, Ağustos ayında meydana gelen tüm olayları gösterecek olan **uspAugustEvents** adında bir stored procedure oluşturmaktır:
#
# <img src = "https://i.hizliresim.com/qhgd4ra.png">
#
# * **uspAugustEvents**i yürüterek elde etmen gereken ilk 5 sonuç.
#
# İlk olarak, Ağustos ayı için etkinlik bilgilerini alacak olan SQL scriptini yaz.
#
# **Ayı ayıklamak için <code>DATEPART(MM, Expression)</code> veya <code>Month(Expression)</code> kullan.**
#
# Şimdi sorgunun en üstüne aşağıdaki kodu ekle:
#
# <img src = "https://i.hizliresim.com/gedzx2i.png">
#
# Procedure'ün adını **uspAugustEvents** ile değiştir ve ardından onu oluşturmak için kodu çalıştır. Procedureünün oluşturulduğunu kontrol et.
#
# <img src = "https://i.hizliresim.com/ggtcl9l.png">
#
# * Management Studio'da listelenen yeni procedureünü görmelisin (önce yenilemen gerekebilir).
#
# İsteğe bağlı olarak, SQL'ini **Nothing ever happens in August.sql** olarak kaydet ve ardından kapat.
#
# ### Nothing ever happens in August.sql
#
# <img src = "https://i.hizliresim.com/pzcksqz.png">

# %% [markdown]
# # 4. Ortalama zorluk
#
# **Steven Moffat'ın Dr Who bölümlerini göstermek için bir procedure oluştur**
#
# **tblAuthor** ve **tblEpisode** tablolarını kullanarak, **Steven Moffat** tarafından yazılan 32 bölümü tarih sırasına göre (en yenisi başta olmak üzere) listelemek için **spMoffats** adlı bir stored procedure oluştur:
#
# <img src = "https://i.hizliresim.com/jg4zgpt.png">
#
# * Veri alman gereken iki tablo
#
# İşte bu stored procedureü çalıştırmanın sonucunun başlangıcı şöyle görünmelidir:
#
# <img src = "https://i.hizliresim.com/qsocqxn.png">
#
# * Stored procedureü çalıştırdığında, bunlar görmen gereken ilk birkaç satırdır.
#
# Şimdi SQL'ini, **Russell** adlı kişiler tarafından kaleme alınan 30 bölümü listeleyen **spRussell** adlı farklı bir stored procedure oluşturacak şekilde değiştir:
#
# <img src = "https://i.hizliresim.com/62udx7u.png">
#
# * İlk birkaç Russell Davies bölümü (yine en son yapılanlar ilk sırada olacak şekilde gösteriliyor)
#
# **Bölümlerini listelemek istediğin yazarın adını veren bir parametreyi tanıtabilsen iyi olmaz mı, bölyece yalnızca bir stored procedure'e ihtiyacın olur.**
#
# İsteğe bağlı olarak, bu gözden geçirilmiş sorguyu **Russell.sql** olarak kaydet ve ardından kapat.
#
# ### Russell.sql
#
# <img src = "https://i.hizliresim.com/la4wybs.png">
#
# <img src = "https://i.hizliresim.com/lmr1hr3.png">
#
# <img src = "https://i.hizliresim.com/a4jro6d.png">

# %% [markdown]
# # 5. Ortalamadan daha zor
#
# **Bölümleri iki şekilde özetlemek için bir procedure oluştur**
#
# Aşağıdakileri göstermek için **spSummariseEpisodes** adlı bir procedure oluştur:
# * en sık görünen 3 arkadaş; sonra ayrı ayrı
# * en sık görünen 3 düşman
#
# Bu stored procedureü çalıştırdığında görmen gereken şunlardır:
#
# <img src = "https://i.hizliresim.com/6nb32hc.png">
#
# * Doctor Who meraklısı için burada pek sürpriz yok.
#
# Procedureünü, en az görünen 5 arkadaş ve en az görünen 5 düşmanı gösterecek şekilde değiştirmek için komut dosyanı değiştir.
#
# İsteğe bağlı olarak, bu sorguyu **Summarise.sql** olarak kaydet ve ardından kapat.
#
# ### Summarise.sql
#
# <img src = "https://i.hizliresim.com/sd14fei.png">
#
# <img src = "https://i.hizliresim.com/2jai3ao.png">
