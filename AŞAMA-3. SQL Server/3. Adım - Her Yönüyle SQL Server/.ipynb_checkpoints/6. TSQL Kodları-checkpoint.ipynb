# %% [markdown]
# # TSQL Komutları
# * SQL haricinde herhangi bir programlama dilinde yapabildiğimiz hemen hemen her şeyi yaptığımız dil **T-SQL**dir.

# %% [markdown]
# # 1. DDL Kodları
# Data Definition Language - Veri Tanımlama Dili
#
# * Sadece TSQLe özel değildir. SQL dilinin de komutlarıdır. Ancak temel için önemlidir.
# * Her SQL Server objesi (database, tablo, kullanıcı, view, procedure) **CREATE** komutu ile oluşturulur, **ALTER** komutuyla değiştirilir ve **DROP** komutuyla silinir. Bu komutlara **DDL komutları** denir.
#
# <img src = "https://i.hizliresim.com/s7ivmru.png" width = 700>
#
# * DDL komutları **KOMUT NESNETÜRÜ NESNEADI** şeklinde tanımlanır.
# * Eğer beraberinde parametre tanımlayacaksan parantez içine yazılır.
#     * Tanımlanan nesne tablo ise parantez içine **SÜTUNADI VERİTÜRÜ** şeklinde yazılır. Eğer otomatik artan bir sütun olacaksa **IDENTITY(1,1)** şeklinde tanımlanır.
#
# * Tablo silineceği zaman da **DROP TABLE ISIMLER** şeklinde silinir.
# * Sorgu yapmadan önce hangi veritabanını seçeceğini **USE DATABASEADI** ile belirtebilirsin.
#
# <img src = "https://i.hizliresim.com/kt7rf8z.png" width = 700>

# %% [markdown]
# # 2. TSQL'de Değişken Kullanımı
#
# ### Tanımlama
#
# * TSQL'de değişken tanımlanabilir.
#
# <img src = "https://i.hizliresim.com/p8ym0wb.png" width =400>
#
# * Değişken tanımlanırken **DECLARE** komutu kullanılır ve değişken olduğunu belirtmek için isminin başına **@** getirilir. Ardından veri türü tanımlanarak değişken oluşur.
# * SQL'de **SELECT** her türlü değeri çekmek için kullanılır. Burada henüz değişken boş olduğu için *NULL* getirir.
#
#
# ### Değer atama
#
# * Tanımlama yaparken değer atanabilir.
# <img src = "https://i.hizliresim.com/smsgfag.png" width = 450>
#
# -------
#
# * Değer sonradan da atanabilir.
# <img src = "https://i.hizliresim.com/j714ktw.png" width = 400>
#
# -------
#
# * Tamsayı değişkenleri **INTEGER** ile tanımlanır.
# * İki farklı değişken kullanarak yeni bir değişken üretilebilir.
# * Aynı tablodan sütunları çekermiş gibi değişkenler **,** ile ayrılabilir ve **AS** ile adlandırılabilir.
#
# <img src = "https://i.hizliresim.com/1vurt04.png" width = 500>
#
# -------
#
# * Değişkenler ayrı ayrı tanımlanabileceği gibi aralarına **,** konularak aynı **DECLARE** içinde de tanımlanabilir.
#
# <img src = "https://i.hizliresim.com/5n7sh3l.png" width = 500>
#
# -------
#
# #### Tablodan dönen değeri değişken olarak atama
# * Önce tablodaki bir satırı seçersin. Daha sonra tanımladığın değişkenleri o satırın sütunları ile eşlersin.
#
# <img src = "https://i.hizliresim.com/ayrxc7m.png" width = 500>
#
# ------
#
# * Tarih değişkeni oluşturma
#
# <img src = "https://i.hizliresim.com/qazhm0n.png" width = 500>
#
# *******
#
# ### Özet
# * SQL Serverda değişken **DECLARE** komutu ile tanımlanır.
# * Değişkene bir isim verilir ve başına **@** getirilir.
# * Daha sonra **AS** diyerek değişkenin türü tanımlanır.
# * **SET** ile değişkenin ismi kullanılarak değişkene değer verilir.
# * Tanımlanan bu değişken üzerinden matematiksel, tarihsel ve string işlemleri türüne göre yapılabilir.
# * Veritabanından dönen değeri değişkene atarken **SELECT** ile değişken adı ve sütun adı eşlenir. Ancak bunun için tablodan tek satır dönmesi gerekir. Birden fazla değer dönerse son değeri alır.

# %% [markdown]
# # 3. String Functions
#
#
# * TSQL'de string işlemlerini gerçekleştiren fonksiyonlar
# * https://docs.microsoft.com/en-us/sql/t-sql/functions/string-functions-transact-sql?view=sql-server-ver16
#
# -------
#
# ### SUBSTRING
# * Bir string ifadenin bir kısmını alan fonksiyon
#
# * <CODE>SUBSTRING(expression, start, length)</CODE>
#     * expression: string ifade
#     * start: substring başlangıcı
#     * length: uzunluğu
#
# <img src = "https://i.hizliresim.com/6upkoxo.png" width = 400>
#
# -------
#
# ### LOWER, UPPER
#
# #### LOWER
# * String ifadeyi küçük harfli yapan fonksiyon
#
# #### UPPER
# * String ifadeyi büyük harfli yapan fonksiyon
#
# <img src = "https://i.hizliresim.com/9twoy6q.png" width = 500>
#
# ------
#
# ### String Birleştirme
#
# * İki string **+** ile yanyana getirilerek birleştirilebilir.
#
# <img src = "https://i.hizliresim.com/3wyrm4r.png" width = 500>
#
# ------
#
# ### RIGHT, LEFT
# * Substringe benzer fonksiyonlar
#
# #### RIGHT
# * Stringi sağdan karakter sayarak alır
#
# #### LEFT
# * Stringi soldan karakter sayarak alır
#
# <img src = "https://i.hizliresim.com/no99xwg.png" width = 600>
#
# -------
#
# ### LTRIM, RTRIM, TRIM
# * Boşlukları temizleyen fonksiyonlar
# * Kirli verileri temizlemek için işe yarar
#
# #### LTRIM
# * Soldan boşluk temizler
#
# #### RTRIM
# * Sağdan boşluk temizler
#
# #### TRIM
# * Soldan ve sağdan boşluk temizler
#
# <img src = "https://i.hizliresim.com/tgg4lu1.png" width = 600>
#
# -------
#
# ### REPLACE
#
# * String içindeki bazı karakterleri başka karakterlerle değiştirmek için kullanılan fonksiyon
#
# * İç içe de kullanılabilir.
#
# <img src = "https://i.hizliresim.com/l97gh0q.png">
#
# -------
#
# ### LEN
# * String ifadenin uzunluğunu getiren fonksiyon
#
# <img src = "https://i.hizliresim.com/b2xeyxj.png" width = 600>
#
#
# --------
#
# ### STRING SPLIT
# * Stringi belirli bir ayraca göre bölerek ayırdığı stringleri tek tek tablo halinde getirir.
# * Diğerlerinden farklı olarak **FROM** dan sonra kullanılır.
#
# <img src = "https://i.hizliresim.com/go41dep.png" width = 600>

# %% [markdown]
# # 4. Datetime Functions
#
# https://docs.microsoft.com/en-us/sql/t-sql/functions/date-and-time-data-types-and-functions-transact-sql?view=sql-server-ver16
#
# ### DATEADD
# * Bir tarihe bir sayı ekleyip başka bir tarih elde etmeye yarayan fonksiyon
# * Fonksiyon içine eklenmek istenen tarih nesnesi, değeri ve tarih girilir.
#
# <img src = "https://i.hizliresim.com/m65bk6b.png">

# %% [markdown]
# ### DATEDIFF
# * İki tarih arasından fark alan fonksiyon
# * Fonksiyon içine farkı alınmak istenen tarih nesnesi, başlangıç ve bitiş tarihleri girilir.
#
# <img src = "https://i.hizliresim.com/s1bapw8.png">

# %% [markdown]
# ### DATEFROMPARTS
# * Fonksiyon içine yıl, ay ve gün girerek date objesi oluşturan fonksiyon
#
# <img src = "https://i.hizliresim.com/qanw94l.png">

# %% [markdown]
# ### DATEPART
# * Tarihin istediğimiz kısmını getiren fonksiyon
#
# <img src = "https://i.hizliresim.com/5w2kmsk.png">
#
# * Sık kullanılan tarih formatları için ayrı ayrı fonksiyonlar da bulunur.
#
# <img src = "https://i.hizliresim.com/qne83jz.png">

# %% [markdown]
# ### GETDATE
# * Anın tarih ve zaman bilgisini getiren fonksiyon
#
# <img src = "https://i.hizliresim.com/593l6jw.png">

# %% [markdown]
# ### Doğum tarihinden yaş bulma
#
# <img src = "https://i.hizliresim.com/i3cs2k2.png">

# %% [markdown]
# # 5. Döngüler
# * TSQL'de for döngüsü yoktur ancak **while** döngüleri vardır.
# * While döngüsü içerisinde kullanmak üzere değişken tanımlamak gerekir. (**@I**)
# * Temel yapı aşağıdaki gibidir;
#
# <img src = "https://i.hizliresim.com/2li33zi.png">
#
# * Döngü değişkenı tanımlanır.
# * Koşula bağlı olarak döngü başlar.
# * Döngü değişkeni döngünün son satırında güncellenir.
# * Koşul devam ettiği sürece işlemler sürer.
#
# ------
#
# * Döngü değişkenini yazdırmak için **SELECT** ya da **PRINT** komutları kullanılır.
#
# <img src = "https://i.hizliresim.com/tb4bgj6.png">
#
# ------
#
# #### Döngü ile kayıt girmek
#
# * 1 saniye gecikme ile bir tabloya tarih anlık tarih bilgisi döngü ile aşağıdaki şekilde girebilir.
#
# <img src = "https://i.hizliresim.com/eoh86fd.png">
#
# ------

# %% [markdown]
# ### İsim ve soyisim databaseleri kullanılarak rastgele kayıtlar oluşturulması
#
# <img src = "https://i.hizliresim.com/rtyphw7.png">
#
# <img src = "https://i.hizliresim.com/gmip8v7.png">
